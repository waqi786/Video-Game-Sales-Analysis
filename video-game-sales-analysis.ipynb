# %% [markdown]
# <a id="A"></a>
# # <div style="text-align:center; border-radius:20px 30px; padding:10px; color:white; margin:0; font-size:120%; font-family:Times New Roman; background-color:black; overflow:hidden"><b> =>  Video Game Sales Analysis  <= </b></div>

# %% [markdown]
# <a id="2"></a>
# # <div style="text-align:center; border-radius:20px 30px; padding:10px; color:white; margin:0; font-size:120%; font-family:Pacifico; background-color:red; overflow:hidden"><b> 🌟 About Author 🌟 </b></div>
#
# <div style="background-color: white; border: 9px solid red; border-radius: 19px; box-shadow: 0 10px 20px rgba(0, 0, 0, 0.1); max-width: 600px; margin: 20px auto; padding: 20px; text-align: center; font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;">
#     <h2 style="color: black; font-weight: bold; margin-bottom: 10px;">WAQAR ALI</h2>
#     <p style="font-size: 16px; line-height: 1.6; color: black; margin-bottom: 20px;">
#         I'm a passionate Data Scientist and Analyst, dedicated to transforming raw data into actionable insights through captivating visualizations. Let's dive into the fascinating world of data and uncover the stories hidden within! 📊🔍✨
#     </p>
# </div>

# %% [markdown]
# <a id="A"></a>
# # <div style="text-align:center; border-radius:20px 30px; padding:10px; color:white; margin:0; font-size:110%; font-family:Times New Roman; background-color:red; overflow:hidden"><b> Importing Libraries </b></div>

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <a id="A"></a>
# # <div style="text-align:center; border-radius:15px 30px; padding:10px; color:white; margin:0; font-size:100%; font-family:Pacifico; background-color:red; overflow:hidden"><b> Load The Dataset </b></div>

# %%
df = pd.read_csv("/kaggle/input/videogamesales/vgsales.csv")
df.head(5)
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %% [markdown]
# <a id="A"></a>
# # <div style="text-align:center; border-radius:15px 30px; padding:10px; color:white; margin:0; font-size:100%; font-family:Pacifico; background-color:red; overflow:hidden"><b> Displaying Column Names </b></div>

# %%
print(df.columns)
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %% [markdown]
# <a id="A"></a>
# # <div style="text-align:center; border-radius:15px 30px; padding:10px; color:white; margin:0; font-size:100%; font-family:Pacifico; background-color:red; overflow:hidden"><b> Dataset Dimensions </b></div>

# %%
df.shape
# Out:
# (16598, 11)

# %% [markdown]
# <a id="A"></a>
# # <div style="text-align:center; border-radius:15px 30px; padding:10px; color:white; margin:0; font-size:100%; font-family:Pacifico; background-color:red; overflow:hidden"><b> Displaying Basic Information about the Dataset </b></div>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %% [markdown]
# <a id="A"></a>
# # <div style="text-align:center; border-radius:15px 30px; padding:10px; color:white; margin:0; font-size:100%; font-family:Pacifico; background-color:red; overflow:hidden"><b> Displaying Summary Statistics </b></div>

# %%
df.describe()
# Out:
#                Rank          Year      NA_Sales      EU_Sales      JP_Sales  \
# count  16598.000000  16327.000000  16598.000000  16598.000000  16598.000000
# mean    8300.605254   2006.406443      0.264667      0.146652      0.077782
# std     4791.853933      5.828981      0.816683      0.505351      0.309291
# min        1.000000   1980.000000      0.000000      0.000000      0.000000
# 25%     4151.250000   2003.000000      0.000000      0.000000      0.000000
# 50%     8300.500000   2007.000000      0.080000      0.020000      0.000000
# 75%    12449.750000   2010.000000      0.240000      0.110000      0.040000
# max    16600.000000   2020.000000     41.490000     29.020000     10.220000
#
#         Other_Sales  Global_Sales
# count  16598.000000  16598.000000
# mean       0.048063      0.537441
# std        0.188588      1.555028
# min        0.000000      0.010000
# 25%        0.000000      0.060000
# 50%        0.010000      0.170000
# 75%        0.040000      0.470000
# ...

# %% [markdown]
# <a id="A"></a>
# # <div style="text-align:center; border-radius:15px 30px; padding:10px; color:white; margin:0; font-size:100%; font-family:Pacifico; background-color:red; overflow:hidden"><b> Null Values Count </b></div>

# %%
df.isnull().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %% [markdown]
# <a id="A"></a>
# # <div style="text-align:center; border-radius:15px 30px; padding:10px; color:white; margin:0; font-size:100%; font-family:Pacifico; background-color:red; overflow:hidden"><b> Percentage of Missing Values in Each Column </b></div>

# %%
(df.isnull().sum()/df.shape[0])*100
# Out:
# Rank            0.000000
# Name            0.000000
# Platform        0.000000
# Year            1.632727
# Genre           0.000000
# Publisher       0.349440
# NA_Sales        0.000000
# EU_Sales        0.000000
# JP_Sales        0.000000
# Other_Sales     0.000000
# Global_Sales    0.000000
# dtype: float64

# %% [markdown]
# <a id="A"></a>
# # <div style="text-align:center; border-radius:15px 30px; padding:10px; color:white; margin:0; font-size:90%; font-family:Pacifico; background-color:red; overflow:hidden"><b> Handling Missing Values in 'Year' and 'Publisher' Columns </b></div>

# %%
df["Year"] = df["Year"].fillna(df["Year"].median())
df["Publisher"] = df["Publisher"].fillna(df["Publisher"].mode()[0])

# %% [markdown]
# <a id="A"></a>
# # <div style="text-align:center; border-radius:15px 30px; padding:10px; color:white; margin:0; font-size:100%; font-family:Pacifico; background-color:red; overflow:hidden"><b> Generating a Correlation Heatmap </b></div>

# %%
plt.figure(figsize=(10, 6))
sns.heatmap(df.select_dtypes(include=['number']).corr(), annot=True, cmap="viridis", linewidths=0.5)
plt.title("Correlation Heatmap")
plt.show()

# %%
df.isnull().sum()
# Out:
# Rank            0
# Name            0
# Platform        0
# Year            0
# Genre           0
# Publisher       0
# NA_Sales        0
# EU_Sales        0
# JP_Sales        0
# Other_Sales     0
# Global_Sales    0
# dtype: int64

# %% [markdown]
# <a id="A"></a>
# # <div style="text-align:center; border-radius:15px 30px; padding:10px; color:white; margin:0; font-size:100%; font-family:Pacifico; background-color:red; overflow:hidden"><b> Unique Values in Each Column </b></div>

# %%
print(df.nunique())
df.shape
# Out:
# Rank            16598
# Name            11493
# Platform           31
# Year               39
# Genre              12
# Publisher         578
# NA_Sales          409
# EU_Sales          305
# JP_Sales          244
# Other_Sales       157
# Global_Sales      623
# dtype: int64
# (16598, 11)

# %% [markdown]
# <a id="A"></a>
# # <div style="text-align:center; border-radius:15px 30px; padding:10px; color:white; margin:0; font-size:100%; font-family:Pacifico; background-color:red; overflow:hidden"><b> Checking for Duplicate Rows in the Dataset </b></div>

# %%
print("Duplicate rows before removal:", df.duplicated().sum())
# Out:
# Duplicate rows before removal: 0

# %% [markdown]
# <a id="A"></a>
# # <div style="text-align:center; border-radius:15px 30px; padding:10px; color:white; margin:0; font-size:100%; font-family:Pacifico; background-color:red; overflow:hidden"><b> Count of Games per Genre </b></div>

# %%
print(df["Genre"].value_counts())
# Out:
# Genre
# Action          3316
# Sports          2346
# Misc            1739
# Role-Playing    1488
# Shooter         1310
# Adventure       1286
# Racing          1249
# Platform         886
# Simulation       867
# Fighting         848
# Strategy         681
# Puzzle           582
# Name: count, dtype: int64

# %% [markdown]
# <a id="A"></a>
# # <div style="text-align:center; border-radius:15px 30px; padding:10px; color:white; margin:0; font-size:100%; font-family:Pacifico; background-color:red; overflow:hidden"><b> Global Sales Trend Over the Years </b></div>

# %%
df.groupby("Year")["Global_Sales"].sum().plot(kind="line", figsize=(12, 5), marker="o", color="red")
plt.title("Global Sales Trend Over the Years")
plt.xlabel("Year")
plt.ylabel("Total Global Sales (in millions)")
plt.grid(True)
plt.show()

# %% [markdown]
# <a id="A"></a>
# # <div style="text-align:center; border-radius:15px 30px; padding:10px; color:white; margin:0; font-size:100%; font-family:Pacifico; background-color:red; overflow:hidden"><b> Top 10 Most Popular Gaming Platforms </b></div>

# %%
plt.figure(figsize=(12, 5))
sns.barplot(x=df["Platform"].value_counts().index[:10], 
            y=df["Platform"].value_counts().values[:10], palette="bright")
plt.title("Top 10 Most Popular Gaming Platforms")
plt.xlabel("Platform")
plt.ylabel("Number of Games Released")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# <a id="A"></a>
# # <div style="text-align:center; border-radius:15px 30px; padding:10px; color:white; margin:0; font-size:100%; font-family:Pacifico; background-color:red; overflow:hidden"><b> Game Genre Distribution (Pie Chart) </b></div>

# %%
df["Genre"].value_counts().plot(kind="pie", autopct="%1.1f%%", figsize=(8, 8), cmap="coolwarm")
plt.title("Game Genre Distribution")
plt.ylabel("")
plt.show()

# %% [markdown]
# <a id="A"></a>
# # <div style="text-align:center; border-radius:15px 30px; padding:10px; color:white; margin:0; font-size:100%; font-family:Pacifico; background-color:red; overflow:hidden"><b> Top 10 Game Publishers by Number of Games Released </b></div>

# %%
top_publishers = df["Publisher"].value_counts().nlargest(10)

plt.figure(figsize=(12,5))
sns.barplot(x=top_publishers.index, y=top_publishers.values, palette="plasma")
plt.title("Top 10 Game Publishers")
plt.xlabel("Publisher")
plt.ylabel("Number of Games")
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# <a id="A"></a>
# # <div style="text-align:center; border-radius:15px 30px; padding:10px; color:white; margin:0; font-size:100%; font-family:Pacifico; background-color:red; overflow:hidden"><b> Top 10 Gaming Platforms by Global Sales </b></div>

# %%
top_platforms = df.groupby("Platform")["Global_Sales"].sum().sort_values(ascending=False)[:10]
plt.figure(figsize=(12, 6))
sns.barplot(y=top_platforms.index, x=top_platforms.values, palette="magma")
plt.title("Top 10 Platforms by Global Sales")
plt.xlabel("Total Global Sales (in millions)")
plt.ylabel("Platform")
plt.show()

# %% [markdown]
# <a id="A"></a>
# # <div style="text-align:center; border-radius:15px 30px; padding:10px; color:white; margin:0; font-size:100%; font-family:Pacifico; background-color:red; overflow:hidden"><b> Total Sales Distribution Across Regions </b></div>

# %%
sales_data = df[["NA_Sales", "EU_Sales", "JP_Sales", "Other_Sales"]].sum()

plt.figure(figsize=(10, 5))
sns.barplot(x=sales_data.index, y=sales_data.values, palette="bright")
plt.title("Regional Sales Distribution")
plt.xlabel("Region")
plt.ylabel("Total Sales (in millions)")
plt.grid(True)
plt.show()
